# %% [markdown]
# ! degree greater than 3 consumes the entire RAM

# %%
#!conda install seaborn -y

# %%
# import libraries
import pandas as pd
import numpy as np
import seaborn as sns

# %%
# import datasets
X = pd.read_csv("dataset_normalised.csv")
y = pd.read_csv("labnf.csv")

# %%
X.head()
# Out:
#   Ticker  SimFinId Currency  Fiscal Year Fiscal Period Report Date  \
# 0      A     45846      USD         2010            Q3  2010-07-31
# 1      A     45846      USD         2010            Q4  2010-10-31
# 2      A     45846      USD         2011            Q1  2011-01-31
# 3      A     45846      USD         2011            Q2  2011-04-30
# 4      A     45846      USD         2011            Q3  2011-07-31
#
#   Publish Date Restated Date  Shares (Basic)  Shares (Diluted)  ...  \
# 0   2010-10-06    2010-10-06        0.013189          0.013262  ...
# 1   2010-12-20    2011-12-16        0.013075          0.013413  ...
# 2   2011-03-09    2011-03-09        0.013189          0.013376  ...
# 3   2011-06-07    2011-06-07        0.013189          0.013376  ...
# 4   2011-09-07    2011-09-07        0.013227          0.013451  ...
#
#    Total Current Liabilities  Long Term Debt  Total Noncurrent Liabilities  \
# 0                   0.009165        0.006773                      0.015508
# 1                   0.009686        0.006809                      0.015518
# 2                   0.004417        0.006664                      0.015309
# 3                   0.005002        0.006681                      0.014763
# 4                   0.004728        0.006748                      0.014634
#
#    Total Liabilities  Share Capital & Additional Paid-In Capital  \
# 0           0.012695                                    0.055579
# 1           0.012950                                    0.055888
# 2           0.010308                                    0.056873
# 3           0.010283                                    0.057378
# 4           0.010079                                    0.058060
#
#    Treasury Stock  Retained Earnings  Total Equity  \
# 0        0.965186           0.190487      0.066599
# 1        0.964960           0.191052      0.067596
# 2        0.963789           0.191426      0.067837
# 3        0.963789           0.191812      0.069293
# 4        0.962956           0.192451      0.069853
#
#    Total Liabilities & Equity  Price_Present
# 0                    0.011541   3.266000e-07
# 1                    0.012297   4.062000e-07
# 2                    0.010202   4.604000e-07
# 3                    0.010969   4.769000e-07
# 4                    0.011101   3.568000e-07
#
# [5 rows x 31 columns]

# %%
y.head()
# Out:
#    Label  Price_Future
# 0      0         41.48
# 1      0         43.95
# 2      0         48.71
# 3      1         35.69
# 4      2         36.66

# %%
# numberical column that are needed for training
numeric_columns=['Shares (Basic)',
       'Shares (Diluted)', 'Cash, Cash Equivalents & Short Term Investments',
       'Accounts & Notes Receivable', 'Inventories', 'Total Current Assets',
       'Property, Plant & Equipment, Net',
       'Long Term Investments & Receivables', 'Other Long Term Assets',
       'Total Noncurrent Assets', 'Total Assets', 'Payables & Accruals',
       'Short Term Debt', 'Total Current Liabilities', 'Long Term Debt',
       'Total Noncurrent Liabilities', 'Total Liabilities',
       'Share Capital & Additional Paid-In Capital', 'Treasury Stock',
       'Retained Earnings', 'Total Equity', 'Total Liabilities & Equity',
       'Price_Present']
X_train = X[numeric_columns]
X_train
# Out:
#        Shares (Basic)  Shares (Diluted)  \
# 0            0.013189          0.013262
# 1            0.013075          0.013413
# 2            0.013189          0.013376
# 3            0.013189          0.013376
# 4            0.013227          0.013451
# ...               ...               ...
# 58823        0.002851          0.002827
# 58824        0.002866          0.002841
# 58825        0.002884          0.002859
# 58826        0.002906          0.002987
# 58827        0.002946          0.003124
#
#        Cash, Cash Equivalents & Short Term Investments  \
# 0                                             0.016228
# 1                                             0.018553
# 2                                             0.018476
# 3                                             0.020836
# 4                                             0.021719
# ...                                                ...
# 58823                                         0.002584
# 58824                                         0.002597
# 58825                                         0.002630
# 58826                                         0.002788
# 58827                                         0.003028
#
#        Accounts & Notes Receivable  Inventories  Total Current Assets  \
# 0                         0.002050     0.009389              0.011391
# 1                         0.002255     0.009771              0.012253
# 2                         0.002216     0.010876              0.009133
# 3                         0.002382     0.011640              0.010122
# 4                         0.002380     0.012241              0.010374
# ...                            ...          ...                   ...
# 58823                     0.000122     0.000000              0.000890
# 58824                     0.000137     0.000000              0.000880
# 58825                     0.000142     0.000000              0.000889
# 58826                     0.000155     0.000000              0.000941
# 58827                     0.000173     0.000000              0.001022
#
#        Property, Plant & Equipment, Net  Long Term Investments & Receivables  \
# 0                              0.018365                             0.000530
# 1                              0.018454                             0.000553
# 2                              0.018462                             0.000522
# 3                              0.018547                             0.000479
# 4                              0.018531                             0.000475
# ...                                 ...                                  ...
# 58823                          0.014978                             0.000000
# 58824                          0.014986                             0.000000
# 58825                          0.015002                             0.000032
# 58826                          0.015021                             0.000023
# 58827                          0.015037                             0.000000
#
#        Other Long Term Assets  Total Noncurrent Assets  ...  \
# 0                    0.006310                 0.012129  ...
# 1                    0.006675                 0.012404  ...
# 2                    0.006469                 0.012266  ...
# 3                    0.006733                 0.012448  ...
# 4                    0.006684                 0.012409  ...
# ...                       ...                      ...  ...
# 58823                0.000717                 0.006951  ...
# 58824                0.000699                 0.006943  ...
# 58825                0.000702                 0.006966  ...
# 58826                0.000696                 0.006967  ...
# 58827                0.000714                 0.006975  ...
#
#        Total Current Liabilities  Long Term Debt  \
# 0                       0.009165        0.006773
# 1                       0.009686        0.006809
# 2                       0.004417        0.006664
# 3                       0.005002        0.006681
# 4                       0.004728        0.006748
# ...                          ...             ...
# 58823                   0.000173        0.000698
# 58824                   0.000156        0.000698
# 58825                   0.000185        0.000698
# 58826                   0.000177        0.000698
# 58827                   0.000200        0.000698
#
#        Total Noncurrent Liabilities  Total Liabilities  \
# 0                          0.015508           0.012695
# 1                          0.015518           0.012950
# 2                          0.015309           0.010308
# 3                          0.014763           0.010283
# 4                          0.014634           0.010079
# ...                             ...                ...
# 58823                      0.006477           0.003326
# 58824                      0.006475           0.003317
# 58825                      0.006479           0.003333
# 58826                      0.006482           0.003331
# 58827                      0.006487           0.003345
#
#        Share Capital & Additional Paid-In Capital  Treasury Stock  \
# 0                                        0.055579        0.965186
# 1                                        0.055888        0.964960
# 2                                        0.056873        0.963789
# 3                                        0.057378        0.963789
# 4                                        0.058060        0.962956
# ...                                           ...             ...
# 58823                                    0.010714        0.999833
# 58824                                    0.010848        0.999833
# 58825                                    0.010970        0.999833
# 58826                                    0.011153        0.999833
# 58827                                    0.011366        0.999833
#
#        Retained Earnings  Total Equity  Total Liabilities & Equity  \
# 0               0.190487      0.066599                    0.011541
# 1               0.191052      0.067596                    0.012297
# 2               0.191426      0.067837                    0.010202
# 3               0.191812      0.069293                    0.010969
# 4               0.192451      0.069853                    0.011101
# ...                  ...           ...                         ...
# 58823           0.184304      0.061652                    0.000969
# 58824           0.184261      0.061645                    0.000958
# 58825           0.184234      0.061661                    0.000980
# 58826           0.184235      0.061728                    0.001014
# 58827           0.184239      0.061813                    0.001072
#
#        Price_Present
# 0       3.266000e-07
# 1       4.062000e-07
# 2       4.604000e-07
# 3       4.769000e-07
# 4       3.568000e-07
# ...              ...
# 58823   2.224000e-07
# 58824   1.874000e-07
# 58825   2.649000e-07
# 58826   3.263000e-07
# 58827   3.828000e-07
#
# [58828 rows x 23 columns]

# %%
y_train = y["Label"].to_numpy()
y_train
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LogisticRegression

# %%
# create polynomial features
scores = []
poly = PolynomialFeatures(degree=2)

X_train_poly = poly.fit_transform(X_train)
clf = LogisticRegression(max_iter=1000)
clf.fit(X_train_poly,y_train)

clf.score(X_train_poly,y_train)
# Out:
# 0.46142993132521926
