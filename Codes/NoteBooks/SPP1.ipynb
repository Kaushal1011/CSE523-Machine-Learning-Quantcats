# %%
import pandas as pd 
import numpy as np
import seaborn as sns
fundamen_data=pd.read_csv("./datasets/fundamental_data.csv")
import pandas as pd
price_df=pd.read_csv("./labels6p.csv")

# %%
fundamen_data.head()
# Out:
#   Ticker  SimFinId Currency  Fiscal Year Fiscal Period Report Date  \
# 0      A     45846      USD         2010            Q3  2010-07-31
# 1      A     45846      USD         2010            Q4  2010-10-31
# 2      A     45846      USD         2011            Q1  2011-01-31
# 3      A     45846      USD         2011            Q2  2011-04-30
# 4      A     45846      USD         2011            Q3  2011-07-31
#
#   Publish Date Restated Date  Shares (Basic)  Shares (Diluted)  ...  \
# 0   2010-10-06    2010-10-06     347000000.0       352000000.0  ...
# 1   2010-12-20    2011-12-16     344000000.0       356000000.0  ...
# 2   2011-03-09    2011-03-09     347000000.0       355000000.0  ...
# 3   2011-06-07    2011-06-07     347000000.0       355000000.0  ...
# 4   2011-09-07    2011-09-07     348000000.0       357000000.0  ...
#
#    Short Term Debt  Total Current Liabilities  Long Term Debt  \
# 0     1.501000e+09               2.917000e+09    2.177000e+09
# 1     1.501000e+09               3.083000e+09    2.190000e+09
# 2     1.000000e+06               1.406000e+09    2.138000e+09
# 3     0.000000e+00               1.592000e+09    2.144000e+09
# 4     0.000000e+00               1.505000e+09    2.168000e+09
#
#    Total Noncurrent Liabilities  Total Liabilities  \
# 0                  3.373000e+09         6290000000
# 1                  3.377000e+09         6460000000
# 2                  3.299000e+09         4705000000
# 3                  3.096000e+09         4688000000
# 4                  3.048000e+09         4553000000
#
#    Share Capital & Additional Paid-In Capital  Treasury Stock  \
# 0                                7.861000e+09   -7.986000e+09
# 1                                7.910000e+09   -8.038000e+09
# 2                                8.066000e+09   -8.308000e+09
# 3                                8.146000e+09   -8.308000e+09
# 4                                8.254000e+09   -8.500000e+09
#
#    Retained Earnings  Total Equity  Total Liabilities & Equity
# 0       3.152000e+09  2.810000e+09                  9100000000
# 1       3.444000e+09  3.236000e+09                  9696000000
# 2       3.637000e+09  3.339000e+09                  8044000000
# 3       3.837000e+09  3.961000e+09                  8649000000
# 4       4.167000e+09  4.200000e+09                  8753000000
#
# [5 rows x 30 columns]

# %%
price_df.head()
# Out:
#    Unnamed: 0 Ticker Price_Present Price_Future Label
# 0           0      A         32.67        41.48     0
# 1           1      A         40.63        43.95     0
# 2           2      A         46.05        48.71     2
# 3           3      A          47.7        35.69     1
# 4           4      A         35.69        36.66     2

# %%
fundamen_data["Price_Present"]=price_df["Price_Present"]

# %%
fundamen_data["Price_Future"]=price_df["Price_Future"]

# %%
fundamen_data["Label"]=price_df["Label"]

# %%
fundamen_data.head()
# Out:
#   Ticker  SimFinId Currency  Fiscal Year Fiscal Period Report Date  \
# 0      A     45846      USD         2010            Q3  2010-07-31
# 1      A     45846      USD         2010            Q4  2010-10-31
# 2      A     45846      USD         2011            Q1  2011-01-31
# 3      A     45846      USD         2011            Q2  2011-04-30
# 4      A     45846      USD         2011            Q3  2011-07-31
#
#   Publish Date Restated Date  Shares (Basic)  Shares (Diluted)  ...  \
# 0   2010-10-06    2010-10-06     347000000.0       352000000.0  ...
# 1   2010-12-20    2011-12-16     344000000.0       356000000.0  ...
# 2   2011-03-09    2011-03-09     347000000.0       355000000.0  ...
# 3   2011-06-07    2011-06-07     347000000.0       355000000.0  ...
# 4   2011-09-07    2011-09-07     348000000.0       357000000.0  ...
#
#    Total Noncurrent Liabilities  Total Liabilities  \
# 0                  3.373000e+09         6290000000
# 1                  3.377000e+09         6460000000
# 2                  3.299000e+09         4705000000
# 3                  3.096000e+09         4688000000
# 4                  3.048000e+09         4553000000
#
#    Share Capital & Additional Paid-In Capital  Treasury Stock  \
# 0                                7.861000e+09   -7.986000e+09
# 1                                7.910000e+09   -8.038000e+09
# 2                                8.066000e+09   -8.308000e+09
# 3                                8.146000e+09   -8.308000e+09
# 4                                8.254000e+09   -8.500000e+09
#
#    Retained Earnings  Total Equity  Total Liabilities & Equity  Price_Present  \
# 0       3.152000e+09  2.810000e+09                  9100000000          32.67
# 1       3.444000e+09  3.236000e+09                  9696000000          40.63
# 2       3.637000e+09  3.339000e+09                  8044000000          46.05
# 3       3.837000e+09  3.961000e+09                  8649000000           47.7
# 4       4.167000e+09  4.200000e+09                  8753000000          35.69
#
#    Price_Future  Label
# 0         41.48      0
# 1         43.95      0
# 2         48.71      2
# 3         35.69      1
# 4         36.66      2
#
# [5 rows x 33 columns]

# %%
clean_fundamen=fundamen_data.loc[((fundamen_data.Price_Present!=fundamen_data.Price_Future) | (fundamen_data.Label!=fundamen_data.Ticker))]

# %%
clean_fundamen.head()
# Out:
#   Ticker  SimFinId Currency  Fiscal Year Fiscal Period Report Date  \
# 0      A     45846      USD         2010            Q3  2010-07-31
# 1      A     45846      USD         2010            Q4  2010-10-31
# 2      A     45846      USD         2011            Q1  2011-01-31
# 3      A     45846      USD         2011            Q2  2011-04-30
# 4      A     45846      USD         2011            Q3  2011-07-31
#
#   Publish Date Restated Date  Shares (Basic)  Shares (Diluted)  ...  \
# 0   2010-10-06    2010-10-06     347000000.0       352000000.0  ...
# 1   2010-12-20    2011-12-16     344000000.0       356000000.0  ...
# 2   2011-03-09    2011-03-09     347000000.0       355000000.0  ...
# 3   2011-06-07    2011-06-07     347000000.0       355000000.0  ...
# 4   2011-09-07    2011-09-07     348000000.0       357000000.0  ...
#
#    Total Noncurrent Liabilities  Total Liabilities  \
# 0                  3.373000e+09         6290000000
# 1                  3.377000e+09         6460000000
# 2                  3.299000e+09         4705000000
# 3                  3.096000e+09         4688000000
# 4                  3.048000e+09         4553000000
#
#    Share Capital & Additional Paid-In Capital  Treasury Stock  \
# 0                                7.861000e+09   -7.986000e+09
# 1                                7.910000e+09   -8.038000e+09
# 2                                8.066000e+09   -8.308000e+09
# 3                                8.146000e+09   -8.308000e+09
# 4                                8.254000e+09   -8.500000e+09
#
#    Retained Earnings  Total Equity  Total Liabilities & Equity  Price_Present  \
# 0       3.152000e+09  2.810000e+09                  9100000000          32.67
# 1       3.444000e+09  3.236000e+09                  9696000000          40.63
# 2       3.637000e+09  3.339000e+09                  8044000000          46.05
# 3       3.837000e+09  3.961000e+09                  8649000000           47.7
# 4       4.167000e+09  4.200000e+09                  8753000000          35.69
#
#    Price_Future  Label
# 0         41.48      0
# 1         43.95      0
# 2         48.71      2
# 3         35.69      1
# 4         36.66      2
#
# [5 rows x 33 columns]

# %%
clean_fundamen.describe()
# Out:
#            SimFinId   Fiscal Year  Shares (Basic)  Shares (Diluted)  \
# count  6.300000e+04  63000.000000    6.236700e+04      6.236700e+04
# mean   4.575444e+05   2014.932143    2.561658e+08      2.610256e+08
# std    3.084648e+05      2.935707    1.058990e+09      1.079666e+09
# min    1.800000e+01   1999.000000    1.000000e+00      1.000000e+00
# 25%    1.802790e+05   2013.000000    2.768600e+07      2.803470e+07
# 50%    3.781980e+05   2015.000000    6.434500e+07      6.540552e+07
# 75%    7.055870e+05   2017.000000    1.797000e+08      1.820000e+08
# max    1.085359e+06   2020.000000    2.630961e+10      2.654106e+10
#
#        Cash, Cash Equivalents & Short Term Investments  \
# count                                     6.279400e+04
# mean                                      1.195853e+09
# std                                       6.058894e+09
# min                                      -2.840000e+02
# 25%                                       3.259400e+07
# 50%                                       1.396000e+08
# 75%                                       5.220820e+08
# max                                       1.427800e+11
#
#        Accounts & Notes Receivable   Inventories  Total Current Assets  \
# count                 5.761900e+04  4.342600e+04          6.298000e+04
# mean                  1.020611e+09  8.357998e+08          3.452768e+09
# std                   7.074201e+09  2.644652e+09          1.451761e+10
# min                   0.000000e+00  0.000000e+00         -2.840000e+02
# 25%                   3.029600e+07  3.168202e+07          1.522360e+08
# 50%                   1.549800e+08  1.712950e+08          5.610555e+08
# 75%                   5.990000e+08  6.374442e+08          2.037025e+09
# max                   3.853120e+11  7.662200e+10          5.034650e+11
#
#        Property, Plant & Equipment, Net  Long Term Investments & Receivables  \
# count                      6.178200e+04                         1.790700e+04
# mean                       3.167694e+09                         1.996330e+09
# std                        1.169139e+10                         1.130995e+10
# min                       -3.806298e+09                         0.000000e+00
# 25%                        3.694125e+07                         1.575500e+07
# 50%                        2.605740e+08                         8.889200e+07
# 75%                        1.402978e+09                         4.702680e+08
# max                        2.555560e+11                         2.842170e+11
#
#        ...  Short Term Debt  Total Current Liabilities  Long Term Debt  \
# count  ...     4.158000e+04               6.299600e+04    4.968900e+04
# mean   ...     5.922286e+08               2.502971e+09    3.462249e+09
# std    ...     3.437989e+09               1.067733e+10    1.069198e+10
# min    ...     0.000000e+00              -3.828530e+05   -2.500000e+08
# 25%    ...     3.390251e+06               6.385475e+07    1.041470e+08
# 50%    ...     2.700000e+07               3.185500e+08    7.159880e+08
# 75%    ...     2.520040e+08               1.337703e+09    2.743000e+09
# max    ...     1.746440e+11               3.182890e+11    3.580920e+11
#
#        Total Noncurrent Liabilities  Total Liabilities  \
# count                  6.225700e+04       6.300000e+04
# mean                   4.340184e+09       6.791829e+09
# std                    1.509053e+10       2.327744e+10
# min                   -2.397250e+09      -2.141441e+09
# 25%                    3.992900e+07       1.301930e+08
# 50%                    5.335230e+08       9.775225e+08
# 75%                    2.762900e+09       4.298104e+09
# max                    3.696910e+11       6.620370e+11
#
#        Share Capital & Additional Paid-In Capital  Treasury Stock  \
# count                                6.196700e+04    2.973000e+04
# mean                                 2.516338e+09   -2.720644e+09
# std                                  7.627736e+09    1.180509e+10
# min                                 -1.999000e+09   -2.304540e+11
# 25%                                  1.560085e+08   -1.180862e+09
# 50%                                  5.166500e+08   -1.874775e+08
# 75%                                  1.787120e+09   -1.593625e+07
# max                                  1.574890e+11    3.838900e+07
#
#        Retained Earnings  Total Equity  Total Liabilities & Equity
# count       6.011100e+04  6.299900e+04                6.300000e+04
# mean        2.773851e+09  3.773731e+09                1.056550e+10
# std         1.552867e+10  1.326139e+10                3.433675e+10
# min        -9.532600e+10 -2.564100e+10                0.000000e+00
# 25%        -9.149850e+07  1.290005e+08                3.563172e+08
# 50%         1.566830e+08  6.545540e+08                1.809499e+09
# 75%         1.428676e+09  2.463810e+09                7.042728e+09
# max         4.216530e+11  4.285630e+11                8.177290e+11
#
# [8 rows x 24 columns]

# %%
clean_fundamen.count()
# Out:
# Ticker                                             63000
# SimFinId                                           63000
# Currency                                           63000
# Fiscal Year                                        63000
# Fiscal Period                                      63000
# Report Date                                        63000
# Publish Date                                       63000
# Restated Date                                      63000
# Shares (Basic)                                     62367
# Shares (Diluted)                                   62367
# Cash, Cash Equivalents & Short Term Investments    62794
# Accounts & Notes Receivable                        57619
# Inventories                                        43426
# Total Current Assets                               62980
# Property, Plant & Equipment, Net                   61782
# Long Term Investments & Receivables                17907
# Other Long Term Assets                             62238
# Total Noncurrent Assets                            62728
# Total Assets                                       63000
# Payables & Accruals                                62714
# Short Term Debt                                    41580
# Total Current Liabilities                          62996
# Long Term Debt                                     49689
# Total Noncurrent Liabilities                       62257
# Total Liabilities                                  63000
# Share Capital & Additional Paid-In Capital         61967
# Treasury Stock                                     29730
# Retained Earnings                                  60111
# Total Equity                                       62999
# Total Liabilities & Equity                         63000
# Price_Present                                      58835
# Price_Future                                       58829
# Label                                              63000
# dtype: int64

# %%
clean_fundamen2=clean_fundamen.dropna(subset=['Price_Future','Price_Present'])

# %%
clean_fundamen2.count()
# Out:
# Ticker                                             58828
# SimFinId                                           58828
# Currency                                           58828
# Fiscal Year                                        58828
# Fiscal Period                                      58828
# Report Date                                        58828
# Publish Date                                       58828
# Restated Date                                      58828
# Shares (Basic)                                     58376
# Shares (Diluted)                                   58376
# Cash, Cash Equivalents & Short Term Investments    58638
# Accounts & Notes Receivable                        53970
# Inventories                                        40870
# Total Current Assets                               58811
# Property, Plant & Equipment, Net                   57844
# Long Term Investments & Receivables                16744
# Other Long Term Assets                             58198
# Total Noncurrent Assets                            58655
# Total Assets                                       58828
# Payables & Accruals                                58597
# Short Term Debt                                    38963
# Total Current Liabilities                          58826
# Long Term Debt                                     46552
# Total Noncurrent Liabilities                       58222
# Total Liabilities                                  58828
# Share Capital & Additional Paid-In Capital         57878
# Treasury Stock                                     28158
# Retained Earnings                                  56141
# Total Equity                                       58827
# Total Liabilities & Equity                         58828
# Price_Present                                      58828
# Price_Future                                       58828
# Label                                              58828
# dtype: int64

# %%
clean_fundamen=clean_fundamen2

# %%
clean_fundamen=clean_fundamen.fillna(0)

# %%
clean_fundamen.count()
# Out:
# Ticker                                             58828
# SimFinId                                           58828
# Currency                                           58828
# Fiscal Year                                        58828
# Fiscal Period                                      58828
# Report Date                                        58828
# Publish Date                                       58828
# Restated Date                                      58828
# Shares (Basic)                                     58828
# Shares (Diluted)                                   58828
# Cash, Cash Equivalents & Short Term Investments    58828
# Accounts & Notes Receivable                        58828
# Inventories                                        58828
# Total Current Assets                               58828
# Property, Plant & Equipment, Net                   58828
# Long Term Investments & Receivables                58828
# Other Long Term Assets                             58828
# Total Noncurrent Assets                            58828
# Total Assets                                       58828
# Payables & Accruals                                58828
# Short Term Debt                                    58828
# Total Current Liabilities                          58828
# Long Term Debt                                     58828
# Total Noncurrent Liabilities                       58828
# Total Liabilities                                  58828
# Share Capital & Additional Paid-In Capital         58828
# Treasury Stock                                     58828
# Retained Earnings                                  58828
# Total Equity                                       58828
# Total Liabilities & Equity                         58828
# Price_Present                                      58828
# Price_Future                                       58828
# Label                                              58828
# dtype: int64

# %%
clean_fundamen.to_csv("dataset_1_6p.csv")

# %%
clean_fundamen=pd.read_csv("dataset_1_6p.csv")
clean_fundamen.describe()
# Out:
#          Unnamed: 0      SimFinId   Fiscal Year  Shares (Basic)  \
# count  58828.000000  5.882800e+04  58828.000000    5.882800e+04
# mean   31516.695723  4.561002e+05   2014.762477    2.600068e+08
# std    18154.174517  3.094505e+05      2.876963    1.082928e+09
# min        0.000000  1.800000e+01   1999.000000    0.000000e+00
# 25%    15871.750000  1.792010e+05   2013.000000    2.723380e+07
# 50%    31521.500000  3.781880e+05   2015.000000    6.393450e+07
# 75%    47193.250000  7.055880e+05   2017.000000    1.800000e+08
# max    62999.000000  1.085359e+06   2020.000000    2.630961e+10
#
#        Shares (Diluted)  Cash, Cash Equivalents & Short Term Investments  \
# count      5.882800e+04                                     5.882800e+04
# mean       2.649305e+08                                     1.218662e+09
# std        1.104104e+09                                     6.140115e+09
# min        0.000000e+00                                     0.000000e+00
# 25%        2.744675e+07                                     3.345600e+07
# 50%        6.484950e+07                                     1.420995e+08
# 75%        1.823127e+08                                     5.312258e+08
# max        2.654106e+10                                     1.427800e+11
#
#        Accounts & Notes Receivable   Inventories  Total Current Assets  \
# count                 5.882800e+04  5.882800e+04          5.882800e+04
# mean                  9.199634e+08  5.833495e+08          3.491419e+09
# std                   6.798329e+09  2.245160e+09          1.473648e+10
# min                   0.000000e+00  0.000000e+00          0.000000e+00
# 25%                   1.639350e+07  0.000000e+00          1.576038e+08
# 50%                   1.212590e+08  4.135250e+07          5.721435e+08
# 75%                   5.333085e+08  3.582025e+08          2.073504e+09
# max                   3.853120e+11  7.327900e+10          5.034650e+11
#
#        Property, Plant & Equipment, Net  ...  Total Noncurrent Liabilities  \
# count                      5.882800e+04  ...                  5.882800e+04
# mean                       3.163914e+09  ...                  4.285066e+09
# std                        1.174912e+10  ...                  1.505207e+10
# min                       -3.806298e+09  ...                 -2.397250e+09
# 25%                        3.378536e+07  ...                  3.647150e+07
# 50%                        2.503685e+08  ...                  5.119960e+08
# 75%                        1.367635e+09  ...                  2.693624e+09
# max                        2.555560e+11  ...                  3.696910e+11
#
#        Total Liabilities  Share Capital & Additional Paid-In Capital  \
# count       5.882800e+04                                5.882800e+04
# mean        6.835340e+09                                2.496729e+09
# std         2.354231e+10                                7.630913e+09
# min        -2.141441e+09                               -9.446000e+08
# 25%         1.337462e+08                                1.448175e+08
# 50%         9.829910e+08                                5.026950e+08
# 75%         4.292500e+09                                1.768310e+09
# max         6.620370e+11                                1.574890e+11
#
#        Treasury Stock  Retained Earnings  Total Equity  \
# count    5.882800e+04       5.882800e+04  5.882800e+04
# mean    -1.316608e+09       2.728238e+09  3.844743e+09
# std      8.343771e+09       1.538363e+10  1.338728e+10
# min     -2.304540e+11      -9.532600e+10 -2.564100e+10
# 25%     -1.619970e+08      -6.704085e+07  1.365072e+08
# 50%      0.000000e+00       1.317635e+08  6.720960e+08
# 75%      0.000000e+00       1.355143e+09  2.517094e+09
# max      3.838900e+07       4.216530e+11  4.015580e+11
#
#        Total Liabilities & Equity  Price_Present  Price_Future         Label
# count                5.882800e+04   5.882800e+04  5.882800e+04  58828.000000
# mean                 1.068008e+10   2.996048e+04  2.805772e+04      0.959883
# std                  3.472629e+10   1.684409e+06  1.628787e+06      0.846160
# min                  0.000000e+00   1.000000e-02  1.000000e-02      0.000000
# 25%                  3.680082e+08   1.451000e+01  1.450000e+01      0.000000
# 50%                  1.825716e+09   3.158000e+01  3.204000e+01      1.000000
# 75%                  7.101819e+09   5.924000e+01  6.063000e+01      2.000000
# max                  7.884820e+11   1.000000e+08  1.000000e+08      2.000000
#
# [8 rows x 28 columns]

# %%
LabnF=pd.DataFrame()

# %%
LabnF["Label"]=clean_fundamen["Label"]
LabnF["Price_Future"]=clean_fundamen["Price_Future"]

# %%
LabnF.head()
# Out:
#    Label  Price_Future
# 0      0         41.48
# 1      0         43.95
# 2      2         48.71
# 3      1         35.69
# 4      2         36.66

# %%
LabnF.describe()
# Out:
#               Label  Price_Future
# count  58828.000000  5.882800e+04
# mean       0.959883  2.805772e+04
# std        0.846160  1.628787e+06
# min        0.000000  1.000000e-02
# 25%        0.000000  1.450000e+01
# 50%        1.000000  3.204000e+01
# 75%        2.000000  6.063000e+01
# max        2.000000  1.000000e+08

# %%
clean_fundamen.drop(columns=['Label', 'Price_Future'],inplace=True)

# %%
# from sklearn import preprocessing we will try this later
clean_fundamen.select_dtypes(include=np.number).columns
clean_fundamen.drop(columns=["Unnamed: 0"],inplace=True)

# %%
features_to_normalize = ['Shares (Basic)',
       'Shares (Diluted)', 'Cash, Cash Equivalents & Short Term Investments',
       'Accounts & Notes Receivable', 'Inventories', 'Total Current Assets',
       'Property, Plant & Equipment, Net',
       'Long Term Investments & Receivables', 'Other Long Term Assets',
       'Total Noncurrent Assets', 'Total Assets', 'Payables & Accruals',
       'Short Term Debt', 'Total Current Liabilities', 'Long Term Debt',
       'Total Noncurrent Liabilities', 'Total Liabilities',
       'Share Capital & Additional Paid-In Capital', 'Treasury Stock',
       'Retained Earnings', 'Total Equity', 'Total Liabilities & Equity',
       'Price_Present']
# could be ['A','B'] 

## Norm

clean_fundamen[features_to_normalize] = clean_fundamen[features_to_normalize].apply(lambda x:(x-x.min()) / (x.max()-x.min()))

# %%
clean_fundamen.head()
# Out:
#   Ticker  SimFinId Currency  Fiscal Year Fiscal Period Report Date  \
# 0      A     45846      USD         2010            Q3  2010-07-31
# 1      A     45846      USD         2010            Q4  2010-10-31
# 2      A     45846      USD         2011            Q1  2011-01-31
# 3      A     45846      USD         2011            Q2  2011-04-30
# 4      A     45846      USD         2011            Q3  2011-07-31
#
#   Publish Date Restated Date  Shares (Basic)  Shares (Diluted)  ...  \
# 0   2010-10-06    2010-10-06        0.013189          0.013262  ...
# 1   2010-12-20    2011-12-16        0.013075          0.013413  ...
# 2   2011-03-09    2011-03-09        0.013189          0.013376  ...
# 3   2011-06-07    2011-06-07        0.013189          0.013376  ...
# 4   2011-09-07    2011-09-07        0.013227          0.013451  ...
#
#    Total Current Liabilities  Long Term Debt  Total Noncurrent Liabilities  \
# 0                   0.009165        0.006773                      0.015508
# 1                   0.009686        0.006809                      0.015518
# 2                   0.004417        0.006664                      0.015309
# 3                   0.005002        0.006681                      0.014763
# 4                   0.004728        0.006748                      0.014634
#
#    Total Liabilities  Share Capital & Additional Paid-In Capital  \
# 0           0.012695                                    0.055579
# 1           0.012950                                    0.055888
# 2           0.010308                                    0.056873
# 3           0.010283                                    0.057378
# 4           0.010079                                    0.058060
#
#    Treasury Stock  Retained Earnings  Total Equity  \
# 0        0.965186           0.190487      0.066599
# 1        0.964960           0.191052      0.067596
# 2        0.963789           0.191426      0.067837
# 3        0.963789           0.191812      0.069293
# 4        0.962956           0.192451      0.069853
#
#    Total Liabilities & Equity  Price_Present
# 0                    0.011541   3.266000e-07
# 1                    0.012297   4.062000e-07
# 2                    0.010202   4.604000e-07
# 3                    0.010969   4.769000e-07
# 4                    0.011101   3.568000e-07
#
# [5 rows x 31 columns]

# %%
clean_fundamen.describe()
# Out:
#            SimFinId   Fiscal Year  Shares (Basic)  Shares (Diluted)  \
# count  5.882800e+04  58828.000000    58828.000000      58828.000000
# mean   4.561002e+05   2014.762477        0.009883          0.009982
# std    3.094505e+05      2.876963        0.041161          0.041600
# min    1.800000e+01   1999.000000        0.000000          0.000000
# 25%    1.792010e+05   2013.000000        0.001035          0.001034
# 50%    3.781880e+05   2015.000000        0.002430          0.002443
# 75%    7.055880e+05   2017.000000        0.006842          0.006869
# max    1.085359e+06   2020.000000        1.000000          1.000000
#
#        Cash, Cash Equivalents & Short Term Investments  \
# count                                     58828.000000
# mean                                          0.008535
# std                                           0.043004
# min                                           0.000000
# 25%                                           0.000234
# 50%                                           0.000995
# 75%                                           0.003721
# max                                           1.000000
#
#        Accounts & Notes Receivable   Inventories  Total Current Assets  \
# count                 58828.000000  58828.000000          58828.000000
# mean                      0.002388      0.007961              0.006935
# std                       0.017644      0.030639              0.029270
# min                       0.000000      0.000000              0.000000
# 25%                       0.000043      0.000000              0.000313
# 50%                       0.000315      0.000564              0.001136
# 75%                       0.001384      0.004888              0.004118
# max                       1.000000      1.000000              1.000000
#
#        Property, Plant & Equipment, Net  Long Term Investments & Receivables  \
# count                      58828.000000                         58828.000000
# mean                           0.026874                             0.002203
# std                            0.045300                             0.023822
# min                            0.000000                             0.000000
# 25%                            0.014806                             0.000000
# 50%                            0.015641                             0.000000
# 75%                            0.019949                             0.000016
# max                            1.000000                             1.000000
#
#        ...  Total Current Liabilities  Long Term Debt  \
# count  ...               58828.000000    58828.000000
# mean   ...                   0.008012        0.008250
# std    ...                   0.034183        0.026587
# min    ...                   0.000000        0.000000
# 25%    ...                   0.000207        0.000701
# 50%    ...                   0.001011        0.001590
# 75%    ...                   0.004280        0.005925
# max    ...                   1.000000        1.000000
#
#        Total Noncurrent Liabilities  Total Liabilities  \
# count                  58828.000000       58828.000000
# mean                       0.017959           0.013516
# std                        0.040453           0.035446
# min                        0.000000           0.000000
# 25%                        0.006541           0.003426
# 50%                        0.007819           0.004704
# 75%                        0.013682           0.009687
# max                        1.000000           1.000000
#
#        Share Capital & Additional Paid-In Capital  Treasury Stock  \
# count                                58828.000000    58828.000000
# mean                                     0.021721        0.994121
# std                                      0.048165        0.036200
# min                                      0.000000        0.000000
# 25%                                      0.006876        0.999131
# 50%                                      0.009135        0.999833
# 75%                                      0.017123        0.999833
# max                                      1.000000        1.000000
#
#        Retained Earnings  Total Equity  Total Liabilities & Equity  \
# count       58828.000000  58828.000000                58828.000000
# mean            0.189668      0.069021                    0.013545
# std             0.029757      0.031337                    0.044042
# min             0.000000      0.000000                    0.000000
# 25%             0.184261      0.060341                    0.000467
# 50%             0.184645      0.061594                    0.002315
# 75%             0.187012      0.065913                    0.009007
# max             1.000000      1.000000                    1.000000
#
#        Price_Present
# count   5.882800e+04
# mean    2.996047e-04
# std     1.684409e-02
# min     0.000000e+00
# 25%     1.450000e-07
# 50%     3.157000e-07
# 75%     5.923000e-07
# max     1.000000e+00
#
# [8 rows x 25 columns]

# %%
clean_fundamen.to_csv("dataset_normalised_6p.csv",index=False)

# %%
LabnF.to_csv("labnf_6p.csv",index=False)

# %%
from sklearn.linear_model import LogisticRegression

# %%
numeric_columns=['Shares (Basic)',
       'Shares (Diluted)', 'Cash, Cash Equivalents & Short Term Investments',
       'Accounts & Notes Receivable', 'Inventories', 'Total Current Assets',
       'Property, Plant & Equipment, Net',
       'Long Term Investments & Receivables', 'Other Long Term Assets',
       'Total Noncurrent Assets', 'Total Assets', 'Payables & Accruals',
       'Short Term Debt', 'Total Current Liabilities', 'Long Term Debt',
       'Total Noncurrent Liabilities', 'Total Liabilities',
       'Share Capital & Additional Paid-In Capital', 'Treasury Stock',
       'Retained Earnings', 'Total Equity', 'Total Liabilities & Equity',
       'Price_Present']
X,y=clean_fundamen[numeric_columns],LabnF["Label"]

# %%
clf = LogisticRegression(random_state=0,solver='lbfgs', max_iter=1000).fit(X, y)

# %%
clf.score(X, y) # First time score = 0.4612089481199429
# Out:
# 0.39163323587407356

# %%
# lets try without scaling down data
clean_fundamen=pd.read_csv("dataset_1.csv")
X,y=clean_fundamen[numeric_columns],LabnF["Label"]
clf = LogisticRegression(random_state=0,solver='lbfgs', max_iter=1000).fit(X, y)
clf.score(X, y)
# Out:
# 0.3807370639831373

# %%
clean_fundamen=pd.read_csv("dataset_1.csv")
X,y=clean_fundamen[numeric_columns],LabnF["Label"]
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
clf = make_pipeline(StandardScaler(), SVC(gamma='auto'))
clf.fit(X, y)

# %%
clf.score(X,y) # Firstime score 0.46618956959271096
# Out:
# 0.46618956959271096

# %%
## Lets try logisitc regression with sklearn default standard scalar
clean_fundamen=pd.read_csv("dataset_1_6p.csv")
X,y=clean_fundamen[numeric_columns],LabnF["Label"]
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
clf = make_pipeline(StandardScaler(), LogisticRegression(random_state=0,solver='lbfgs', max_iter=1000))
clf.fit(X, y),clf.score(X,y) # First time score 0.46125994424423744
# Out:
# (Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('logisticregression',
#                   LogisticRegression(max_iter=1000, random_state=0))]),
#  0.3925851635275719)

# %%
clean_fundamen=pd.read_csv("dataset_1_6p.csv")
X,y=clean_fundamen[numeric_columns],LabnF["Label"]
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
Xtrain,Xtest,Ytrain,Ytest=train_test_split(X, y, test_size=0.33, random_state=42)
trainscores=[]
testscores=[]
for i in range(2,32,2):
    clf = make_pipeline(StandardScaler(), RandomForestClassifier( max_depth=i,random_state=0))
    # Full overfit
    clf.fit(Xtrain, Ytrain)
    trainscore=clf.score(Xtrain,Ytrain)
    trainscores.append(trainscore)
    testscore=clf.score(Xtest,Ytest)
    testscores.append(testscore)
    print("Max_Depth: ",i," Score Train:",trainscore)
    print("Max_Depth: ",i," Score Test:",testscore)
# Out:
# Max_Depth:  2  Score Train: 0.40729182523976254
# Max_Depth:  2  Score Test: 0.4055835994643041
# Max_Depth:  4  Score Train: 0.4185822296645862
# Max_Depth:  4  Score Test: 0.4138765839085196
# Max_Depth:  6  Score Train: 0.44245699497640434
# Max_Depth:  6  Score Test: 0.424178427938601
# Max_Depth:  8  Score Train: 0.4895214898259502
# Max_Depth:  8  Score Test: 0.43180179252086126
# Max_Depth:  10  Score Train: 0.5672349926422083
# Max_Depth:  10  Score Test: 0.44086741526733286
# Max_Depth:  12  Score Train: 0.6734662810168975
# Max_Depth:  12  Score Test: 0.4434943854950036
# Max_Depth:  14  Score Train: 0.786624042218501
# Max_Depth:  14  Score Test: 0.443545894715154
# Max_Depth:  16  Score Train: 0.8837722636626579
# Max_Depth:  16  Score Test: 0.4395796847635727
# Max_Depth:  18  Score Train: 0.9542802050032984
# Max_Depth:  18  Score Test: 0.43875553724116617
# Max_Depth:  20  Score Train: 0.9846501243213072
# Max_Depth:  20  Score Test: 0.4336561244462759
# Max_Depth:  22  Score Train: 0.9964225909575278
# Max_Depth:  22  Score Test: 0.4307716081178531
# Max_Depth:  24  Score Train: 0.9993149642259096
# Max_Depth:  24  Score Test: 0.4286597300916864
# Max_Depth:  26  Score Train: 0.9998731415233166
# Max_Depth:  26  Score Test: 0.427217471927475
# Max_Depth:  28  Score Train: 0.9999746283046633
# Max_Depth:  28  Score Test: 0.4288142577521376
# Max_Depth:  30  Score Train: 0.9999492566093267
# Max_Depth:  30  Score Test: 0.426959925826723

# %%
import matplotlib.pyplot as plt

plt.plot(range(2,32,2),trainscores,label="train accuracy")
plt.plot(range(2,32,2),testscores,label="test accuracy")
plt.ylim(0.4, 0.7)
plt.legend()

# %%
clf = make_pipeline(StandardScaler(), RandomForestClassifier( max_depth=14,random_state=0))
    # Full overfit
clf.fit(Xtrain, Ytrain)
trainscore=clf.score(Xtrain,Ytrain)
testscore=clf.score(Xtest,Ytest)
print("Score Train:",trainscore)
print("Score Test:",testscore)
print("Score Overall:",clf.score(X,y))
# Out:
# Score Train: 0.786624042218501
# Score Test: 0.443545894715154
# Score Overall: 0.6734038213095804

# %%
clf = make_pipeline(StandardScaler(), RandomForestClassifier( max_depth=30,random_state=0))
    # Full overfit
clf.fit(Xtrain, Ytrain)
trainscore=clf.score(Xtrain,Ytrain)
testscore=clf.score(Xtest,Ytest)
print("Score Train:",trainscore)
print("Score Test:",testscore)
print("Score Overall:",clf.score(X,y))
# Out:
# Score Train: 0.9999492566093267
# Score Test: 0.426959925826723
# Score Overall: 0.8108553749915006
